# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
import requests  # 외부에 있는 이미지를 가져올 때 사용
from io import BytesIO

# %%
url = 'https://cdn.pixabay.com/photo/2018/10/01/09/21/pets-3715733_960_720.jpg'

response = requests.get(url)
pic = Image.open(BytesIO(response.content))

# %% [markdown]
# 이미지 출력(PIL)

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x639 at 0x17E7F8C9250>

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# PIL 이미지를 array형으로 형변환
#    - np.asarray()

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (639, 960, 3)

# %%
plt.imshow(pic_arr)
plt.show()
