# %% [markdown]
# 데이터 로드

# %%
import pandas as pd

ss = pd.read_csv("D:/_data/stock predict/삼성전자.csv", thousands=',', encoding='CP949')
ss = ss.drop(range(20, 1120), axis=0)
ki = pd.read_csv("D:/_data/stock predict/키움증권.csv", thousands=',', encoding='CP949')
ki = ki.drop(range(20, 1060), axis=0)

ss
# Out:
#             일자     시가     고가     저가     종가 전일비  Unnamed: 6   등락률         거래량  \
# 0   2021/12/17  76800  78000  76800  78000   ▲         200  0.26  11802494.0
# 1   2021/12/16  78500  78500  77400  77800   ▲         200  0.26  11996128.0
# 2   2021/12/15  76400  77600  76300  77600   ▲         600  0.78   9584939.0
# 3   2021/12/14  76500  77200  76200  77000   ▲         200  0.26  10976660.0
# 4   2021/12/13  77200  78300  76500  76800   ▼        -100 -0.13  15038750.0
# 5   2021/12/10  77400  77600  76800  76900   ▼       -1300 -1.66   9155219.0
# 6   2021/12/09  77400  78200  77000  78200   ▲         800  1.03  21604528.0
# 7   2021/12/08  78300  78600  77100  77400               0  0.00  21558340.0
# 8   2021/12/07  76100  77700  75600  77400   ▲        1100  1.44  19232453.0
# 9   2021/12/06  75100  76700  74900  76300   ▲         700  0.93  16391250.0
# 10  2021/12/03  75600  76000  74100  75600   ▼        -200 -0.26  18330240.0
# 11  2021/12/02  73900  75800  73800  75800   ▲        1400  1.88  23652940.0
# 12  2021/12/01  72000  74800  71600  74400   ▲        3100  4.35  21954856.0
# 13  2021/11/30  73200  73900  70500  71300   ▼       -1000 -1.38  30364841.0
# 14  2021/11/29  71700  73000  71400  72300               0  0.00  16682559.0
# 15  2021/11/26  73500  74100  72000  72300   ▼       -1400 -1.90  13002242.0
# 16  2021/11/25  75100  75100  73600  73700   ▼       -1100 -1.47  12559258.0
# 17  2021/11/24  76000  76200  74100  74800   ▼        -500 -0.66  15652305.0
# 18  2021/11/23  76000  76000  74500  75300   ▲         400  0.53  22029195.0
# 19  2021/11/22  73300  75200  73000  74900   ▲        3700  5.20  27506623.0
#
#        금액(백만)   신용비       개인       기관   외인(수량)      외국계     프로그램    외인비
# 0    914987.0  0.00  -733323  -907696        0  -257019   757837  51.78
# 1    934244.0  0.13  -442445  -261746  -105777   571543   822030  51.78
# 2    738592.0  0.14 -1118059  -654764  1095947  1946258  1706254  51.79
# 3    841447.0  0.14   198293 -1487295  1005909   804186  -132070  51.77
# 4   1163285.0  0.13  -181359   184966  -151301 -1388477  -606534  51.75
# 5    705966.0  0.13  1797829 -1071153  -728679  -505955 -1714088  51.75
# 6   1681184.0  0.14 -1671678  -491078  2768853  2796574  3486578  51.77
# 7   1662979.0  0.14 -2524520  2586682   703379  -941476    48232  51.72
# 8   1477888.0  0.14 -2997907  -547244  4216958  3518986   123462  51.71
# 9   1245309.0  0.14 -3062604   576498  2508191  2146417  2070776  51.64
# 10  1375861.0  0.15   133267  -157689  -630400   467310  -532651  51.60
# 11  1778785.0  0.15 -6603764  -164462  6327924  5789997  5214948  51.61
# 12  1610885.0  0.15 -6250521   415580  5498391  5601567  3706678  51.50
# 13  2183678.0  0.15  1834720 -2841806  1600552   370200   939616  51.41
# 14  1206606.0  0.15 -2395401  3021851  -494165  -566353  -525529  51.38
# 15   944378.0  0.15  1825155 -1070320 -1157622  -560900 -1313864  51.39
# 16   929571.0  0.15   694786  -179371  -353300  -143417  -704752  51.41
# 17  1174196.0  0.15   701745 -2258726  1484318  1421283  -596182  51.41
# 18  1656722.0  0.16 -2177512 -2811514  4884832  5578065  1247451  51.39
# 19  2047228.0  0.16 -8689803  3034399  5716921  4760374  3500256  51.31

# %% [markdown]
# 데이터 전처리

# %%
import numpy as np
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, Input, LSTM, Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6680/516235546.py in <module>
#       3 from tensorflow.keras.layers import Dense, Input, LSTM, Dropout
#       4
# ----> 5 from sklearn.preprocessing import MinMaxScaler
#       6 from sklearn.model_selection import train_test_split
#       7 import matplotlib.pyplot as plt
#
# C:\ProgramData\Anaconda3\envs\tf270gpu\lib\site-packages\sklearn\__init__.py in <module>
#      80     from . import _distributor_init  # noqa: F401
#      81     from . import __check_build  # noqa: F401
# ---> 82     from .base import clone
#      83     from .utils._show_versions import show_versions
#      84
#
# C:\ProgramData\Anaconda3\envs\tf270gpu\lib\site-packages\sklearn\base.py in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#
# C:\ProgramData\Anaconda3\envs\tf270gpu\lib\site-packages\sklearn\utils\__init__.py in <module>
#      26 from ..exceptions import DataConversionWarning
#      27 from .deprecation import deprecated
# ---> 28 from .fixes import np_version, parse_version
#      29 from ._estimator_html_repr import estimator_html_repr
#      30 from .validation import (
#
# C:\ProgramData\Anaconda3\envs\tf270gpu\lib\site-packages\sklearn\utils\fixes.py in <module>
#      18 import scipy.sparse as sp
#      19 import scipy
# ---> 20 import scipy.stats
#      21 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      22 import threadpoolctl
#
# ModuleNotFoundError: No module named 'scipy.stats'

# %%
# 인덱스 재배열
ss = ss.loc[::-1].reset_index(drop=True)
ki = ki.loc[::-1].reset_index(drop=True)

ki
# Out:
#             일자      시가      고가      저가      종가 전일비  Unnamed: 6   등락률     거래량  \
# 0   2021/11/22  106000  109000  105000  109000   ▲        3500  3.32   89564
# 1   2021/11/23  107500  107500  105500  107500   ▼       -1500 -1.38   57672
# 2   2021/11/24  107000  107000  105000  105000   ▼       -2500 -2.33   62724
# 3   2021/11/25  105000  106500  104000  105500   ▲         500  0.48   38215
# 4   2021/11/26  104500  106000  102000  103000   ▼       -2500 -2.37   77033
# 5   2021/11/29  100000  104000  100000  102500   ▼        -500 -0.49   78470
# 6   2021/11/30  102500  103000   96000   97500   ▼       -5000 -4.88  169524
# 7   2021/12/01   97000   99800   96600   99600   ▲        2100  2.15   79903
# 8   2021/12/02   98100  104000   98100  103500   ▲        3900  3.92   75890
# 9   2021/12/03  102500  106000  102000  105500   ▲        2000  1.93   65729
# 10  2021/12/06  105500  108500  104000  107500   ▲        2000  1.90   77250
# 11  2021/12/07  107500  108500  106500  108000   ▲         500  0.47   46518
# 12  2021/12/08  108000  109500  107500  107500   ▼        -500 -0.46   49085
# 13  2021/12/09  108500  109000  106500  108000   ▲         500  0.47   62923
# 14  2021/12/10  108000  108500  106500  106500   ▼       -1500 -1.39   28979
# 15  2021/12/13  107000  109500  107000  107500   ▲        1000  0.94   52503
# 16  2021/12/14  106500  109000  106500  107000   ▼        -500 -0.47   64977
# 17  2021/12/15  107000  108000  106500  107500   ▲         500  0.47   23210
# 18  2021/12/16  109500  109500  107000  107500               0  0.00   45031
# 19  2021/12/17  107000  109500  106500  109500   ▲        2000  1.86   60487
#
#     금액(백만)   신용비     개인     기관  외인(수량)    외국계   프로그램    외인비
# 0     9563  0.93 -13426 -10878   24865  23544  24075  25.61
# 1     6143  0.94  11818 -13417   -1065   1528  -8687  25.61
# 2     6620  0.93  26965  -8031  -26006 -17199 -20042  25.51
# 3     4026  0.94  -7183   3216   10319   1666  -3350  25.55
# 4     7991  0.96  14505   5517  -26186 -15546 -25613  25.45
# 5     8007  0.95 -21785   9951   10834   1718   -192  25.49
# 6    16764  0.93  62687 -27749  -59027 -43107 -47586  25.27
# 7     7875  0.91 -18847   4984    8628   8973   9911  25.30
# 8     7705  0.94 -38201  11298   13384  10192  26511  25.35
# 9     6890  0.92 -21284  13087    7616    669   3073  25.38
# 10    8276  0.89 -40876   5377   36004  26747  17436  25.52
# 11    5008  0.87  10363    296  -26729  -5199 -10394  25.41
# 12    5329  0.85  -7038   5396   -4363   1143   -591  25.40
# 13    6788  0.86  -3385   7495    6090    970   1767  25.42
# 14    3105  0.85   2080  -6921    8941   -798  -1877  25.46
# 15    5695  0.83 -13963   7746    7576    695   8305  25.48
# 16    6974  0.83   4777 -20135   15033  -1107   2477  25.54
# 17    2496  0.81  -4089   1368    -915   5065  -1671  25.54
# 18    4858  0.82    956  13405  -23661 -10182 -12948  25.45
# 19    6576  0.00 -16202   6443       0   7348   8805  25.45

# %%
# 필요한 컬럼만 남겨두기
x_ss = ss.drop(['일자',  '고가', '저가', '종가', '전일비', 'Unnamed: 6', '등락률', '거래량', '금액(백만)',
                '신용비', '개인', '기관', '외인(수량)', '외국계', '프로그램', '외인비'], axis =1)
x_ss = np.array(x_ss)
x_ki = ki.drop(['일자', '고가', '저가', '종가', '전일비', 'Unnamed: 6', '등락률', '거래량', '금액(백만)',
                '신용비',  '개인', '기관', '외인(수량)', '외국계', '프로그램', '외인비'], axis =1)
x_ki = np.array(x_ki)


# '일자', '시가', '고가', '저가', '종가', '전일비', 'Unnamed: 6', '등락률', '거래량', '금액(백만)', '신용비', '개인', '기관', '외인(수량)', '외국계', '프로그램', '외인비'

# x_ss = x_ss.reshape(20,)
# x_ki = x_ki.reshape(20,)
x_ss.shape
# Out:
# (20, 1)

# %%
# split 함수 정의
def split_xy2(dataset, time_steps, y_column):
    x, y = list(), list()
    for i in range(len(dataset)):
        x_end_number = i + time_steps
        y_end_number = x_end_number + y_column
        if y_end_number > len(dataset):
            break
        tmp_x = dataset[i : x_end_number]
        tmp_y = dataset[x_end_number : y_end_number]
        x.append(tmp_x)
        y.append(tmp_y)
    return np.array(x), np.array(y)        

x_ssp, y_ssp = split_xy2(x_ss, 4, 3)
x_kip, y_kip = split_xy2(x_ki, 4, 3)

x_ssp.shape, y_ssp.shape
# Out:
# ((14, 4, 1), (14, 3, 1))

# %%
# 삼성 데이터 train_test_split 적용
x1_train, x1_test, y1_train, y1_test = train_test_split(x_ssp, y_ssp, train_size=0.8, random_state=66)

# 키움 데이터 train_test_split 적용
x2_train, x2_test, y2_train, y2_test = train_test_split(x_kip, y_kip, train_size=0.8, random_state=66)

# %% [markdown]
# 모델 구성

# %%
#삼성 input
input1 = Input(shape=(4,))
dense1_1 = Dense(32, activation='relu')(input1)
dense1_2 = Dense(16, activation='relu')(dense1_1)
output1 = Dense(4, activation='relu')(dense1_2)

#키움 input
input2 = Input(shape=(4,))
dense2_1 = Dense(32, activation='relu')(input2)
dense2_2 = Dense(16, activation='relu')(dense2_1)
output2 = Dense(4, activation='relu')(dense2_2)

#앙상블
from tensorflow.keras.layers import concatenate
merge1 = concatenate([output1, output2])

#삼성 out
output1_1 = Dense(16, activation='relu')(merge1)
output1_2 = Dense(8)(output1_1)
ss_output = Dense(3)(output1_2)

#키움 out
output2_1 = Dense(16, activation='relu')(merge1)
output2_2 = Dense(8)(output2_1)
ku_output = Dense(3)(output2_2)

model = Model(inputs=[input1, input2], outputs=[ss_output, ku_output])

# %%
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 4)]          0
# __________________________________________________________________________________________________
# input_10 (InputLayer)           [(None, 4)]          0
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 32)           160         input_9[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 32)           160         input_10[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 16)           528         dense_44[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 16)           528         dense_47[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 4)            68          dense_45[0][0]
# __________________________________________________________________________________________________
# dense_49 (Dense)                (None, 4)            68          dense_48[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8)            0           dense_46[0][0]
#                                                                  dense_49[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 16)           144         concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 16)           144         concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 8)            136         dense_50[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 8)            136         dense_53[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 3)            27          dense_51[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 3)            27          dense_54[0][0]
# ==================================================================================================
# Total params: 2,126
# Trainable params: 2,126
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# 컴파일 & 훈련

# %%
from tensorflow.keras.callbacks import EarlyStopping
model.compile(loss='mae', optimizer='adam')
es = EarlyStopping(monitor='val_loss', mode='auto', patience=20, restore_best_weights=True)
hist = model.fit([x1_train,x2_train], [y1_train, y2_train], epochs=1000, batch_size=1,
                 validation_split=0.3, callbacks=[es])
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 22ms/step - loss: 187064.1562 - dense_52_loss: 83597.3594 - dense_55_loss: 103466.8125 - val_loss: 172891.9219 - val_dense_52_loss: 82453.5469 - val_dense_55_loss: 90438.3750
# Epoch 2/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 165009.9062 - dense_52_loss: 82049.0859 - dense_55_loss: 82960.8281 - val_loss: 151804.5312 - val_dense_52_loss: 81068.5312 - val_dense_55_loss: 70736.0000
# Epoch 3/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 142930.7812 - dense_52_loss: 79989.1797 - dense_55_loss: 62941.6016 - val_loss: 127998.7109 - val_dense_52_loss: 78117.1172 - val_dense_55_loss: 49881.5977
# Epoch 4/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 116496.2578 - dense_52_loss: 76217.7422 - dense_55_loss: 40278.5117 - val_loss: 99949.3984 - val_dense_52_loss: 73271.1094 - val_dense_55_loss: 26678.2910
# Epoch 5/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 96670.8359 - dense_52_loss: 70397.8906 - dense_55_loss: 26272.9551 - val_loss: 88548.3281 - val_dense_52_loss: 66179.7031 - val_dense_55_loss: 22368.6250
# Epoch 6/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 85837.3203 - dense_52_loss: 62478.4297 - dense_55_loss: 23358.8887 - val_loss: 76996.5000 - val_dense_52_loss: 57778.3477 - val_dense_55_loss: 19218.1504
# Epoch 7/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 71678.6094 - dense_52_loss: 53997.8125 - dense_55_loss: 17680.7988 - val_loss: 61688.2109 - val_dense_52_loss: 49243.1562 - val_dense_55_loss: 12445.0547
# Epoch 8/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 58117.7383 - dense_52_loss: 44615.4062 - dense_55_loss: 13502.3389 - val_loss: 49775.1211 - val_dense_52_loss: 38315.4844 - val_dense_55_loss: 11459.6348
# Epoch 9/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 42266.6211 - dense_52_loss: 31256.3594 - dense_55_loss: 11010.2637 - val_loss: 29765.5254 - val_dense_52_loss: 22602.4492 - val_dense_55_loss: 7163.0776
# Epoch 10/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 25451.1211 - dense_52_loss: 18128.7793 - dense_55_loss: 7322.3433 - val_loss: 21892.4883 - val_dense_52_loss: 16235.2891 - val_dense_55_loss: 5657.2007
# Epoch 11/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 20817.4941 - dense_52_loss: 13305.7881 - dense_55_loss: 7511.7061 - val_loss: 17536.0977 - val_dense_52_loss: 9378.3604 - val_dense_55_loss: 8157.7363
# Epoch 12/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14958.1250 - dense_52_loss: 7777.6299 - dense_55_loss: 7180.4946 - val_loss: 10217.5820 - val_dense_52_loss: 4437.6543 - val_dense_55_loss: 5779.9272
# Epoch 13/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7407.2378 - dense_52_loss: 3335.0854 - dense_55_loss: 4072.1523 - val_loss: 7244.2061 - val_dense_52_loss: 3204.2278 - val_dense_55_loss: 4039.9785
# Epoch 14/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 9522.7119 - dense_52_loss: 4694.8076 - dense_55_loss: 4827.9053 - val_loss: 6332.1230 - val_dense_52_loss: 2839.9297 - val_dense_55_loss: 3492.1934
# Epoch 15/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 8522.2754 - dense_52_loss: 3677.1809 - dense_55_loss: 4845.0947 - val_loss: 7292.7490 - val_dense_52_loss: 2789.0105 - val_dense_55_loss: 4503.7383
# Epoch 16/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7502.5195 - dense_52_loss: 3160.9517 - dense_55_loss: 4341.5674 - val_loss: 8806.7686 - val_dense_52_loss: 3593.9058 - val_dense_55_loss: 5212.8628
# Epoch 17/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7476.0737 - dense_52_loss: 3096.5132 - dense_55_loss: 4379.5605 - val_loss: 6706.5938 - val_dense_52_loss: 2411.2383 - val_dense_55_loss: 4295.3560
# Epoch 18/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 6852.8135 - dense_52_loss: 2745.8225 - dense_55_loss: 4106.9917 - val_loss: 5631.4746 - val_dense_52_loss: 1696.4414 - val_dense_55_loss: 3935.0334
# Epoch 19/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 6849.3384 - dense_52_loss: 2813.5698 - dense_55_loss: 4035.7683 - val_loss: 7355.2363 - val_dense_52_loss: 2859.7434 - val_dense_55_loss: 4495.4927
# Epoch 20/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7712.6729 - dense_52_loss: 3007.1086 - dense_55_loss: 4705.5640 - val_loss: 6283.8057 - val_dense_52_loss: 2345.5923 - val_dense_55_loss: 3938.2136
# Epoch 21/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 6476.4644 - dense_52_loss: 2652.9231 - dense_55_loss: 3823.5413 - val_loss: 5966.1191 - val_dense_52_loss: 2433.5188 - val_dense_55_loss: 3532.6003
# Epoch 22/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 6769.6211 - dense_52_loss: 2692.4868 - dense_55_loss: 4077.1343 - val_loss: 7230.7305 - val_dense_52_loss: 2819.9500 - val_dense_55_loss: 4410.7803
# Epoch 23/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7364.5981 - dense_52_loss: 2895.7378 - dense_55_loss: 4468.8599 - val_loss: 6397.3027 - val_dense_52_loss: 2126.1570 - val_dense_55_loss: 4271.1460
# Epoch 24/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7306.7983 - dense_52_loss: 2995.5642 - dense_55_loss: 4311.2344 - val_loss: 6194.5098 - val_dense_52_loss: 2117.3313 - val_dense_55_loss: 4077.1785
# Epoch 25/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7744.9404 - dense_52_loss: 2996.2737 - dense_55_loss: 4748.6665 - val_loss: 6635.7358 - val_dense_52_loss: 1854.6517 - val_dense_55_loss: 4781.0840
# Epoch 26/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 6619.1821 - dense_52_loss: 2565.1704 - dense_55_loss: 4054.0117 - val_loss: 8675.9072 - val_dense_52_loss: 3782.1477 - val_dense_55_loss: 4893.7598
# Epoch 27/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 8532.7061 - dense_52_loss: 3588.0779 - dense_55_loss: 4944.6284 - val_loss: 6330.4609 - val_dense_52_loss: 2583.8440 - val_dense_55_loss: 3746.6174
# Epoch 28/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 6801.0884 - dense_52_loss: 2716.7170 - dense_55_loss: 4084.3711 - val_loss: 6742.8931 - val_dense_52_loss: 2238.2825 - val_dense_55_loss: 4504.6099
# Epoch 29/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 8194.4482 - dense_52_loss: 3286.4666 - dense_55_loss: 4907.9810 - val_loss: 6555.1982 - val_dense_52_loss: 1965.7148 - val_dense_55_loss: 4589.4834
# Epoch 30/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7444.2847 - dense_52_loss: 2965.3335 - dense_55_loss: 4478.9517 - val_loss: 6387.9497 - val_dense_52_loss: 1767.3900 - val_dense_55_loss: 4620.5596
# Epoch 31/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 5971.0298 - dense_52_loss: 2222.4058 - dense_55_loss: 3748.6235 - val_loss: 6876.1436 - val_dense_52_loss: 2675.7957 - val_dense_55_loss: 4200.3477
# Epoch 32/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7140.0166 - dense_52_loss: 2897.1428 - dense_55_loss: 4242.8735 - val_loss: 6122.5127 - val_dense_52_loss: 2164.4792 - val_dense_55_loss: 3958.0334
# Epoch 33/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7459.6675 - dense_52_loss: 3157.0056 - dense_55_loss: 4302.6621 - val_loss: 6016.6035 - val_dense_52_loss: 2218.7463 - val_dense_55_loss: 3797.8574
# Epoch 34/1000
# 7/7 [==============================] - ETA: 0s - loss: 5041.2500 - dense_52_loss: 1342.7604 - dense_55_loss: 3698.48 - 0s 3ms/step - loss: 6615.6938 - dense_52_loss: 2845.3430 - dense_55_loss: 3770.3501 - val_loss: 5876.1724 - val_dense_52_loss: 1899.6107 - val_dense_55_loss: 3976.5618
# Epoch 35/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7248.1929 - dense_52_loss: 3079.7417 - dense_55_loss: 4168.4517 - val_loss: 6959.0010 - val_dense_52_loss: 2996.2542 - val_dense_55_loss: 3962.7466
# Epoch 36/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 6872.0923 - dense_52_loss: 2873.4551 - dense_55_loss: 3998.6370 - val_loss: 6753.8281 - val_dense_52_loss: 2360.2786 - val_dense_55_loss: 4393.5493
# Epoch 37/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 7489.3892 - dense_52_loss: 3300.7839 - dense_55_loss: 4188.6050 - val_loss: 6648.2070 - val_dense_52_loss: 2551.5762 - val_dense_55_loss: 4096.6304
# Epoch 38/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 5934.3398 - dense_52_loss: 2407.0786 - dense_55_loss: 3527.2610 - val_loss: 7399.9028 - val_dense_52_loss: 3158.2637 - val_dense_55_loss: 4241.6392

# %% [markdown]
# 평가 & 예측

# %%
loss = model.evaluate([x1_test, x2_test], [y1_test, y2_test])
print('loss : ', loss)

pred1 = x_ss[16:20].reshape(1, -1)
pred2 = x_ki[16:20].reshape(1, -1)

ss_pred, ki_pred = model.predict([pred1, pred2])
samsung = ss_pred[-1][-1]
kiwoom = ki_pred[-1][-1]
print('예측값 : ', samsung, kiwoom)
# Out:
# 1/1 [==============================] - 0s 14ms/step - loss: 8373.7568 - dense_52_loss: 3244.9080 - dense_55_loss: 5128.8491
# loss :  [8373.7568359375, 3244.907958984375, 5128.84912109375]
# 예측값 :  79477.49 110991.44

# %%
model.save("../_save/stock_wed_mp_{}.h5".format(samsung))

# %% [markdown]
# 데이터 시각화

# %%
loss = hist.history["loss"]
ss_loss = hist.history["dense_6_loss"]
ku_loss = hist.history["dense_9_loss"]
ss_val = hist.history["val_dense_6_loss"]
ku_val = hist.history["val_dense_9_loss"]

epochs = range(1, len(loss)+1)

plt.plot(epochs, loss, 'y--', label="training loss")
plt.plot(epochs, ss_loss, 'r--', label="ss_loss")
plt.plot(epochs, ku_loss, 'b--', label="ku_loss")
plt.plot(epochs, ss_val, 'r:', label="ss_val")
plt.plot(epochs, ku_val, 'b:', label="ku_val")

plt.grid()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17088/1519759607.py in <module>
#       1 loss = hist.history["loss"]
# ----> 2 ss_loss = hist.history["dense_6_loss"]
#       3 ku_loss = hist.history["dense_9_loss"]
#       4 ss_val = hist.history["val_dense_6_loss"]
#       5 ku_val = hist.history["val_dense_9_loss"]
#
# KeyError: 'dense_6_loss'

# %% [markdown]
# 데이터 로드

# %%
model = load_model("../_save/stock_tue_vol_[76790.445].h5")

loss = model.evaluate([x1_test, x2_test], [y1_test, y2_test])
print('loss : ', loss)
ss_pred, ki_pred = model.predict([x1_test, x2_test])
print('예측값 : ', ss_pred[-1], ki_pred[-1])
# Out:
# 1/1 [==============================] - 0s 241ms/step - loss: 3100.8994 - dense_6_loss: 1314.4873 - dense_9_loss: 1786.4121
# loss :  [3100.8994140625, 1314.4873046875, 1786.412109375]
# 예측값 :  [76790.445] [106224.9]
